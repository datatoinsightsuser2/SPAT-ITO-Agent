# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Using cached streamlit-1.44.0-py3-none-any.whl (9.8 MB)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.29.4)
# Collecting pillow<12,>=7.1.0
#   Downloading pillow-11.2.0-cp310-cp310-win_amd64.whl (13.8 MB)
#      ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/13.8 MB 1.4 MB/s eta 0:00:10
#       --------------------------------------- 0.3/13.8 MB 2.4 MB/s eta 0:00:06
#      -- ------------------------------------- 1.0/13.8 MB 5.7 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.8/13.8 MB 17.2 MB/s eta 0:00:01
#      ------------- -------------------------- 4.7/13.8 MB 17.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 5.6/13.8 MB 17.8 MB/s eta 0:00:01
#      ------------------ --------------------- 6.4/13.8 MB 17.9 MB/s eta 0:00:01
#      --------------------- ------------------ 7.4/13.8 MB 18.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 8.2/13.8 MB 18.0 MB/s eta 0:00:01
#      -------------------------- ------------- 9.1/13.8 MB 18.2 MB/s eta 0:00:01
#      ---------------------------- ---------- 10.0/13.8 MB 18.3 MB/s eta 0:00:01
#      ------------------------------ -------- 10.9/13.8 MB 23.4 MB/s eta 0:00:01
#      --------------------------------- ----- 11.7/13.8 MB 21.8 MB/s eta 0:00:01
#      ----------------------------------- --- 12.6/13.8 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  13.5/13.8 MB 19.8 MB/s eta 0:00:01
#      --------------------------------------- 13.8/13.8 MB 18.2 MB/s eta 0:00:00
# Collecting click<9,>=7.0
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Collecting numpy<3,>=1.23
#   Using cached numpy-2.2.4-cp310-cp310-win_amd64.whl (12.9 MB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.5.2)
# Collecting watchdog<7,>=2.1.5
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Collecting pydeck<1,>=0.8.0b4
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting pandas<3,>=1.4.0
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: packaging<25,>=20 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.32.3)
# Collecting toml<2,>=0.10.1
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting blinker<2,>=1.0.0
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting altair<6,>=4.0
#   Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Collecting tenacity<10,>=8.1.0
#   Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting pyarrow>=7.0
#   Using cached pyarrow-19.0.1-cp310-cp310-win_amd64.whl (25.3 MB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: jinja2 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Collecting narwhals>=1.14.2
#   Using cached narwhals-1.33.0-py3-none-any.whl (322 kB)
# Requirement already satisfied: colorama in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#      ------------------------------------- 509.2/509.2 kB 31.2 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#      ---------------------------------------- 347.8/347.8 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: six>=1.5 in c:\users\akshit\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Installing collected packages: pytz, watchdog, tzdata, toml, tenacity, smmap, pyarrow, pillow, numpy, narwhals, click, blinker, pydeck, pandas, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.33.0 numpy-2.2.4 pandas-2.2.3 pillow-11.2.0 pyarrow-19.0.1 pydeck-0.9.1 pytz-2025.2 smmap-5.0.2 streamlit-1.44.0 tenacity-9.0.0 toml-0.10.2 tzdata-2025.2 watchdog-6.0.0
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import uuid
from agent.agent import pet_graph
from agent.utils import _print_event
# Out:
# Graph successfully built.

# %%
st.set_page_config(page_title="🐾 Smart Pet Travel Assistant")
# Out:
# 2025-04-01 21:43:10.972 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
